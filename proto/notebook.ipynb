# %%
x = (1, 2, 3)
y = [1, 2, 3]

print(tuple(x) == tuple(y))
# Out:
# True

# %%
None in ((1, 2), None)
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class C:
    x: int
    y: int

c = C(1, 2)
print(type(c))
# Out:
# <class '__main__.C'>
