# %%
x = (1, 2, 3)
y = [1, 2, 3]

print(tuple(x) == tuple(y))
# Out:
# True

# %%
None in ((1, 2), None)
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class C:
    x: int
    y: int

c = C(1, 2)
print(type(c))
# Out:
# <class '__main__.C'>

# %%
import numpy as np

np.array([])
# Out:
# array([], dtype=float64)

# %%
import pickle

fpath_mats = (
    r'D:\WORK\Salvador\repo\model_tuner\test_data\a1_ou_unconn'
    #r'\scott_2025_02_28\OUmapping_0228.pkl'
    r'\scott_2025_03_13\OUmapping_master_compat.pkl'
)

with open(fpath_mats, 'rb') as file:
    data = pickle.load(file)

# %%
print(data['rate']['IT2'])
# Out:
# OUamp     0.000010   0.000100  0.000273  0.000535  0.000798  0.000799  \
# OUstd
# 0.000005       0.0        NaN       0.0       0.0       0.0       0.0
# 0.000050       NaN   0.000000       NaN       NaN       NaN       NaN
# 0.000136       0.0        NaN       0.0       0.0       0.0       NaN
# 0.000268       0.0        NaN       0.0       0.0       0.0       NaN
# 0.000399       0.0        NaN       0.0       0.0       0.0       NaN
# ...            ...        ...       ...       ...       ...       ...
# 0.019747       NaN   7.650888       NaN       NaN       NaN       NaN
# 0.021061       NaN   8.511834       NaN       NaN       NaN       NaN
# 0.022374       NaN   9.417160       NaN       NaN       NaN       NaN
# 0.023687       NaN  10.156805       NaN       NaN       NaN       NaN
# 0.025000       NaN  10.926036       NaN       NaN       NaN       NaN
#
# OUamp     0.001061  0.001323  0.001586  0.001588  ...   0.028989  0.030000  \
# ...

# %%
import numpy as np


np.linspace(0.1, 1.5, 7)
# Out:
# array([0.1       , 0.33333333, 0.56666667, 0.8       , 1.03333333,
#        1.26666667, 1.5       ])

# %%
import pickle

fpath = r"D:\WORK\Salvador\repo\model_tuner\test_data\a1_ou_unconn\scott_2025_03_26\OUmapping_v45_batch21.pkl"

with open(fpath, 'rb') as file:
    data = pickle.load(file)

#type(data['rate']['SOM2'])
data['rate'].keys()
# Out:
# dict_keys(['SOM2', 'VIP2', 'SOM3', 'VIP3', 'ITS4', 'SOM4', 'VIP4', 'SOM5A', 'VIP5A', 'SOM5B', 'VIP5B', 'SOM6', 'VIP6', 'TC', 'TCM', 'HTC', 'IRE', 'IREM', 'TI', 'TIM'])

# %%
import numpy as np

xx = np.linspace(0, 100, 4)
yy = np.linspace(0, -100, 4)
grid = np.array(np.meshgrid(xx, yy)).T.reshape(-1, 2)
grid
# Out:
# array([[   0.        ,    0.        ],
#        [   0.        ,  -33.33333333],
#        [   0.        ,  -66.66666667],
#        [   0.        , -100.        ],
#        [  33.33333333,    0.        ],
#        [  33.33333333,  -33.33333333],
#        [  33.33333333,  -66.66666667],
#        [  33.33333333, -100.        ],
#        [  66.66666667,    0.        ],
#        [  66.66666667,  -33.33333333],
#        [  66.66666667,  -66.66666667],
#        [  66.66666667, -100.        ],
#        [ 100.        ,    0.        ],
#        [ 100.        ,  -33.33333333],
#        [ 100.        ,  -66.66666667],
#        [ 100.        , -100.        ]])

# %%
import numpy as np

#s = np.array([1, 2, 4, 8, 11])
s = np.array([1])
s[1:] - s[:-1]
# Out:
# array([], dtype=int32)

# %%
(1,) * 3
# Out:
# (1, 1, 1)
